# %%
import math

x=n

Tolerance=10**(-12)
NewtonsCubic=x**

def newton(function, dfunction, x, n):

    def f(x):
      f=eval(function)
      return f

    def df(x):
      df=eval(dfunction)

    for intercept in range(1,n):
      i=x-(f(x)/df(x))
      x=i

      print(f"The root is {x} after {n} iterations")

newton()
# Out:
#   File "<ipython-input-1-51ce77233998>", line 5
#     def newton()
#                 ^
# SyntaxError: expected ':'
